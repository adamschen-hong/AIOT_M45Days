# %% [markdown]
# ### 作業1 : 練習使用一個民生物聯網 API，例如空氣、地震等感測站所回傳的紀錄資料。
#            參考資料網址： https://ci.taiwan.gov.tw/dsp/environmental.aspx

# %%
import requests

url = "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/"
response = requests.get(url)
print(response.json())
# Out:
# {'value': [{'name': 'Datastreams', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Datastreams'}, {'name': 'MultiDatastreams', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/MultiDatastreams'}, {'name': 'FeaturesOfInterest', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/FeaturesOfInterest'}, {'name': 'HistoricalLocations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/HistoricalLocations'}, {'name': 'Locations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Locations'}, {'name': 'Observations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Observations'}, {'name': 'ObservedProperties', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/ObservedProperties'}, {'name': 'Sensors', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Sensors'}, {'name': 'Things', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Things'}]}

# %% [markdown]
# ### 作業2 : 練習操作 OGC SensorThings API，將環保局測站位置的資料抓取下來，並且觀察下載資料的內容。
#            參考網址：https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things

# %%
import requests

url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things"
response = requests.get(url)
print(response.json())
# Out:
# {'@iot.count': 10197, '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100', 'value': [{'description': '智慧城鄉空品微型感測器-11113765144', '@iot.id': 1, 'name': '智慧城鄉空品微型感測器-11113765144', 'properties': {'city': '基隆市', 'areaType': '一般社區', 'isMobile': 'false', 'township': '七堵區', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'true', 'stationID': '11113765144', 'locationId': 'TW020201D0506810', 'Description': '廣域SAQ-210', 'areaDescription': '七堵區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-11183695772', '@iot.id': 2, 'name': '智慧城鄉空品微型感測器-11183695772', 'properties': {'city': '臺中市', 'areaType': '社區', 'isMobile': 'false', 'township': '大雅區', 'authority': '行政院環境保護署', 'isDisplay': 'false', 'isOutdoor': 'true', 'stationID': '11183695772', 'locationId': 'TW090208A0507633', 'Description': '廣域SAQ-210', 'areaDescription': '大雅區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-9330689794', '@iot.id': 3, 'name': '智慧城鄉空品微型感測器-9330689794', 'properties': {'city': '苗栗縣', 'areaType': '工業區', 'isMobile': 'false', 'township': '苗栗市', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'true', 'stationID': '9330689794', 'locationId': 'A0191', 'Description': '經昌/CE003', 'areaDescription': '西山工業區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-7518931416', '@iot.id': 4, 'name': '智慧城鄉空品微型感測器-7518931416', 'properties': {'city': '高雄市', 'areaType': '工業區', 'isMobile': 'false', 'township': '林園區', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'false', 'stationID': '7518931416', 'locationId': 'KS-O30404', 'Description': 'Jsene/JsenePM', 'areaDescription': '林園工業區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)/HistoricalLocations' ...

# %% [markdown]
# ### 作業3 : 依據作業 2 所下載的各個環保局測站感測器的描述資料，進一步點選 Datastreams、Locations，以及 Datastreams 點選進入後，點選 Observations 的 URL，觀察所下載到的資料內容，其中 Observations 內部是否包含個別感測器紀錄的資料。

# %%
import requests

url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things"
response = requests.get(url)
things = response.json()

datastreamURL = things['value'][0]['Datastreams@iot.navigationLink']
locationsURL = things['value'][0]['Locations@iot.navigationLink']
datastream = requests.get(datastreamURL).json()
locations = requests.get(locationsURL).json()

observationsURL = datastream['value'][0]['Observations@iot.navigationLink']
observations = requests.get(observationsURL).json()

print('response ==> ', response) 
print('things==> ', things) 

print('datastreamURL ==> ', datastreamURL)  
print('locationsURL ==> ', locationsURL) 
print('observationsURL ==> ', observationsURL)
print('observations ==> ', observations)
# Out:
# response ==>  <Response [200]>
# things==>  {'@iot.count': 10197, '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100', 'value': [{'description': '智慧城鄉空品微型感測器-11113765144', '@iot.id': 1, 'name': '智慧城鄉空品微型感測器-11113765144', 'properties': {'city': '基隆市', 'areaType': '一般社區', 'isMobile': 'false', 'township': '七堵區', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'true', 'stationID': '11113765144', 'locationId': 'TW020201D0506810', 'Description': '廣域SAQ-210', 'areaDescription': '七堵區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-11183695772', '@iot.id': 2, 'name': '智慧城鄉空品微型感測器-11183695772', 'properties': {'city': '臺中市', 'areaType': '社區', 'isMobile': 'false', 'township': '大雅區', 'authority': '行政院環境保護署', 'isDisplay': 'false', 'isOutdoor': 'true', 'stationID': '11183695772', 'locationId': 'TW090208A0507633', 'Description': '廣域SAQ-210', 'areaDescription': '大雅區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(2)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-9330689794', '@iot.id': 3, 'name': '智慧城鄉空品微型感測器-9330689794', 'properties': {'city': '苗栗縣', 'areaType': '工業區', 'isMobile': 'false', 'township': '苗栗市', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'true', 'stationID': '9330689794', 'locationId': 'A0191', 'Description': '經昌/CE003', 'areaDescription': '西山工業區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/HistoricalLocations', 'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/Locations', 'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/MultiDatastreams', 'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(3)/TaskingCapabilities'}, {'description': '智慧城鄉空品微型感測器-7518931416', '@iot.id': 4, 'name': '智慧城鄉空品微型感測器-7518931416', 'properties': {'city': '高雄市', 'areaType': '工業區', 'isMobile': 'false', 'township': '林園區', 'authority': '行政院環境保護署', 'isDisplay': 'true', 'isOutdoor': 'false', 'stationID': '7518931416', 'locationId': 'KS-O30404', 'Description': 'Jsene/JsenePM', 'areaDescription': '林園工業區'}, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)', 'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)/Datastreams', 'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(4)/Historica ...
# datastreamURL ==>  https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams
# locationsURL ==>  https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Locations
# observationsURL ==>  https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)/Observations
# observations ==>  {'@iot.count': 72, 'value': [{'@iot.id': 26138984, 'phenomenonTime': '2021-04-11T09:59:19.000Z', 'result': 73.9, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26138984)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26138984)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26138984)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26138984)/FeatureOfInterest'}, {'@iot.id': 26652013, 'phenomenonTime': '2021-04-11T11:03:19.000Z', 'result': 80.9, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26652013)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26652013)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26652013)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(26652013)/FeatureOfInterest'}, {'@iot.id': 27126827, 'phenomenonTime': '2021-04-11T11:59:19.000Z', 'result': 83.55, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(27126827)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(27126827)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(27126827)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(27126827)/FeatureOfInterest'}, {'@iot.id': 25230209, 'phenomenonTime': '2021-04-11T08:13:19.000Z', 'result': 58.15, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25230209)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25230209)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25230209)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25230209)/FeatureOfInterest'}, {'@iot.id': 25136447, 'phenomenonTime': '2021-04-11T08:01:19.000Z', 'result': 59.07, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25136447)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25136447)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25136447)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25136447)/FeatureOfInterest'}, {'@iot.id': 25151448, 'phenomenonTime': '2021-04-11T08:03:19.000Z', 'result': 59.3, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25151448)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25151448)/MultiDatastream', 'Datastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25151448)/Datastream', 'FeatureOfInterest@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25151448)/FeatureOfInterest'}, {'@iot.id': 25284647, 'phenomenonTime': '2021-04-11T08:19:19.000Z', 'result': 60.08, 'resultTime': None, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25284647)', 'MultiDatastream@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Observations(25 ...
